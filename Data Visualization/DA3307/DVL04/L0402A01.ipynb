# %%
import pandas as pd
import numpy as np

df=pd.read_csv('pokemon_data_gen1_dirty.csv')
df
# Out:
#        #                   Name   Type 1    Type 2     HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass    Poison   45.0    49.0     49.0
# 1      2                Ivysaur    Grass    Poison   60.0    62.0     63.0
# 2      3               Venusaur    Grass    Poison   80.0    82.0      NaN
# 3      4  VenusaurMega Venusaur    Grass    Poison   80.0   100.0      NaN
# 4      5             Charmander     Fire       NaN   39.0    52.0     43.0
# ..   ...                    ...      ...       ...    ...     ...      ...
# 170  169              Dragonite   Dragon    Flying   91.0   134.0     95.0
# 171  170                 Mewtwo  Psychic       NaN  106.0   110.0     90.0
# 172  171    MewtwoMega Mewtwo X  Psychic  Fighting  106.0   190.0    100.0
# 173  172    MewtwoMega Mewtwo Y  Psychic       NaN  106.0   150.0     70.0
# 174  173                    Mew  Psychic       NaN  100.0   100.0    100.0
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df['Name'].duplicated().sum()
# Out:
# 160

# %%
df.loc[df.duplicated(), :]
# Out:
#      #      Name    Type 1 Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 51  32    Raichu  Electric    NaN  60.0    90.0     55.0     90.0      NaN
# 70  69  Arcanine      Fire    NaN  90.0   110.0     80.0    100.0     80.0
#
#     Speed  Generation  Legendary
# 51  110.0           1      False
# 70   95.0           1      False

# %%
df.loc[df.duplicated(keep=False)]
# Out:
#      #      Name    Type 1 Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  69  Arcanine      Fire    NaN  90.0   110.0     80.0    100.0     80.0
# 32  32    Raichu  Electric    NaN  60.0    90.0     55.0     90.0      NaN
# 51  32    Raichu  Electric    NaN  60.0    90.0     55.0     90.0      NaN
# 70  69  Arcanine      Fire    NaN  90.0   110.0     80.0    100.0     80.0
#
#     Speed  Generation  Legendary
# 20   95.0           1      False
# 32  110.0           1      False
# 51  110.0           1      False
# 70   95.0           1      False

# %%
df.loc[df.duplicated(keep= 'first')]
# Out:
#      #      Name    Type 1 Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 51  32    Raichu  Electric    NaN  60.0    90.0     55.0     90.0      NaN
# 70  69  Arcanine      Fire    NaN  90.0   110.0     80.0    100.0     80.0
#
#     Speed  Generation  Legendary
# 51  110.0           1      False
# 70   95.0           1      False

# %%
df.loc[df.duplicated(keep= 'last')]
# Out:
#      #      Name    Type 1 Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  69  Arcanine      Fire    NaN  90.0   110.0     80.0    100.0     80.0
# 32  32    Raichu  Electric    NaN  60.0    90.0     55.0     90.0      NaN
#
#     Speed  Generation  Legendary
# 20   95.0           1      False
# 32  110.0           1      False

# %%
drop_df=df.drop_duplicates(keep='first', inplace=True)
df.duplicated().sum()
# Out:
# 0

# %%
df.loc[(df['Name'] == 'Raichu') | (df['Name'] == 'Arcanine')]
# Out:
#      #      Name    Type 1 Type 2    HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 20  69  Arcanine      Fire    NaN  90.0   110.0     80.0    100.0     80.0
# 32  32    Raichu  Electric    NaN  60.0    90.0     55.0     90.0      NaN
#
#     Speed  Generation  Legendary
# 20   95.0           1      False
# 32  110.0           1      False

# %%
df['Name'].duplicated().sum()
# Out:
# 7

# %%
df=pd.read_csv('pokemon_data_gen1_dirty.csv')
df.head(10)
# Out:
#     #                       Name Type 1  Type 2    HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison  45.0    49.0     49.0
# 1   2                    Ivysaur  Grass  Poison  60.0    62.0     63.0
# 2   3                   Venusaur  Grass  Poison  80.0    82.0      NaN
# 3   4      VenusaurMega Venusaur  Grass  Poison  80.0   100.0      NaN
# 4   5                 Charmander   Fire     NaN  39.0    52.0     43.0
# 5   6                 Charmeleon   Fire     NaN  58.0    64.0     58.0
# 6   7                  Charizard   Fire  Flying  78.0    84.0     78.0
# 7   8  CharizardMega Charizard X   Fire  Dragon  78.0     NaN    111.0
# 8   9  CharizardMega Charizard Y   Fire  Flying  78.0     NaN     78.0
# 9  10                   Squirtle  Water     NaN  44.0    48.0     65.0
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0     65.0     65.0   45.0           1      False
# 1     80.0     80.0   60.0           1      False
# ...

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.isnull().sum()
# Out:
# #              0
# Name           0
# Type 1         0
# Type 2        95
# HP             1
# Attack         2
# Defense        6
# Sp. Atk        2
# Sp. Def        7
# Speed          1
# Generation     0
# Legendary      0
# dtype: int64

# %%
df_drop = df.dropna()
df_drop.head(10)
# Out:
#      #                   Name  Type 1  Type 2    HP  Attack  Defense  Sp. Atk  \
# 0    1              Bulbasaur   Grass  Poison  45.0    49.0     49.0     65.0
# 1    2                Ivysaur   Grass  Poison  60.0    62.0     63.0     80.0
# 6    7              Charizard    Fire  Flying  78.0    84.0     78.0    109.0
# 17  18                 Kakuna     Bug  Poison  45.0    25.0     50.0     25.0
# 18  19               Beedrill     Bug  Poison  65.0    90.0     40.0     45.0
# 19  20  BeedrillMega Beedrill     Bug  Poison  65.0   150.0     40.0     15.0
# 21  21                 Pidgey  Normal  Flying  40.0    45.0     40.0     35.0
# 22  22              Pidgeotto  Normal  Flying  63.0    60.0     55.0     50.0
# 23  23                Pidgeot  Normal  Flying  83.0    80.0     75.0     70.0
# 24  24    PidgeotMega Pidgeot  Normal  Flying  83.0    80.0     80.0    135.0
#
#     Sp. Def  Speed  Generation  Legendary
# 0      65.0   45.0           1      False
# ...

# %%
df_drop.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
df['Attack'].fillna(100, inplace = True)
df.head(10)
# Out:
#     #                       Name Type 1  Type 2    HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison  45.0    49.0     49.0
# 1   2                    Ivysaur  Grass  Poison  60.0    62.0     63.0
# 2   3                   Venusaur  Grass  Poison  80.0    82.0      NaN
# 3   4      VenusaurMega Venusaur  Grass  Poison  80.0   100.0      NaN
# 4   5                 Charmander   Fire     NaN  39.0    52.0     43.0
# 5   6                 Charmeleon   Fire     NaN  58.0    64.0     58.0
# 6   7                  Charizard   Fire  Flying  78.0    84.0     78.0
# 7   8  CharizardMega Charizard X   Fire  Dragon  78.0   100.0    111.0
# 8   9  CharizardMega Charizard Y   Fire  Flying  78.0   100.0     78.0
# 9  10                   Squirtle  Water     NaN  44.0    48.0     65.0
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0     65.0     65.0   45.0           1      False
# 1     80.0     80.0   60.0           1      False
# ...

# %%
x = df['Defense'].mean()
df['Defense'].fillna(x, inplace = True)
df.head(10)
# Out:
#     #                       Name Type 1  Type 2    HP  Attack     Defense  \
# 0   1                  Bulbasaur  Grass  Poison  45.0    49.0   49.000000
# 1   2                    Ivysaur  Grass  Poison  60.0    62.0   63.000000
# 2   3                   Venusaur  Grass  Poison  80.0    82.0   69.284024
# 3   4      VenusaurMega Venusaur  Grass  Poison  80.0   100.0   69.284024
# 4   5                 Charmander   Fire  Poison  39.0    52.0   43.000000
# 5   6                 Charmeleon   Fire  Poison  58.0    64.0   58.000000
# 6   7                  Charizard   Fire  Flying  78.0    84.0   78.000000
# 7   8  CharizardMega Charizard X   Fire  Dragon  78.0     NaN  111.000000
# 8   9  CharizardMega Charizard Y   Fire  Flying  78.0     NaN   78.000000
# 9  10                   Squirtle  Water  Poison  44.0    48.0   65.000000
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0     65.0     65.0   45.0           1      False
# 1     80.0     80.0   60.0           1      False
# ...

# %%
x = df['Type 2'].mode()[0]
df['Type 2'].fillna(x, inplace = True)
df.head(10)
# Out:
#     #                       Name Type 1  Type 2    HP  Attack  Defense  \
# 0   1                  Bulbasaur  Grass  Poison  45.0    49.0     49.0
# 1   2                    Ivysaur  Grass  Poison  60.0    62.0     63.0
# 2   3                   Venusaur  Grass  Poison  80.0    82.0      NaN
# 3   4      VenusaurMega Venusaur  Grass  Poison  80.0   100.0      NaN
# 4   5                 Charmander   Fire  Poison  39.0    52.0     43.0
# 5   6                 Charmeleon   Fire  Poison  58.0    64.0     58.0
# 6   7                  Charizard   Fire  Flying  78.0    84.0     78.0
# 7   8  CharizardMega Charizard X   Fire  Dragon  78.0     NaN    111.0
# 8   9  CharizardMega Charizard Y   Fire  Flying  78.0     NaN     78.0
# 9  10                   Squirtle  Water  Poison  44.0    48.0     65.0
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0     65.0     65.0   45.0           1      False
# 1     80.0     80.0   60.0           1      False
# ...

# %%
df.isnull().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Type 2        0
# HP            1
# Attack        2
# Defense       0
# Sp. Atk       2
# Sp. Def       7
# Speed         1
# Generation    0
# Legendary     0
# dtype: int64
