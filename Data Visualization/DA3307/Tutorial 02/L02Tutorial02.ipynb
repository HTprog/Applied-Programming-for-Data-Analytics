# %% [markdown]
# # MUHAMMAD HIDAYAT BIN MOHD YUSOF

# %% [markdown]
# # 20FTT2910

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('Training_dataset_01.csv')

# %%
df

# %%
df.head(10)
# Out:
#        name  gender race/ethnicity         lunch  math score  reading score  \
# 0     Jenan  female        group B      standard          72             72
# 1       Bel  female        group C      standard          69             90
# 2  Jannelle  female        group B      standard          90             95
# 3   Jo-anne    male        group A  free/reduced          47             57
# 4       Ola    male        group C      standard          76             78
# 5     Angie  female        group B      standard          71             83
# 6     Marga  female        group B      standard          88             95
# 7    Buckie    male        group B  free/reduced          40             43
# 8   Aloisia    male        group D  free/reduced          64             64
# 9    Seward  female        group B  free/reduced          38             60
#
#    writing score
# 0             74
# 1             88
# 2             93
# 3             44
# 4             75
# 5             78
# ...

# %%
df.columns
# Out:
# Index(['name', 'gender', 'race/ethnicity', 'lunch', 'math score',
#        'reading score', 'writing score'],
#       dtype='object')

# %%
df['name'].value_counts()
# Out:
# Nelia      2
# Desiri     2
# Risa       1
# Wittie     1
# Eldin      1
#           ..
# Lizette    1
# Pail       1
# Flinn      1
# Willy      1
# Baxy       1
# Name: name, Length: 247, dtype: int64

# %%
df[['name','math score','reading score','writing score']].head(6)
# Out:
#        name  math score  reading score  writing score
# 0     Jenan          72             72             74
# 1       Bel          69             90             88
# 2  Jannelle          90             95             93
# 3   Jo-anne          47             57             44
# 4       Ola          76             78             75
# 5     Angie          71             83             78

# %%
df[['name','math score','reading score','writing score']][0:6]
# Out:
#        name  math score  reading score  writing score
# 0     Jenan          72             72             74
# 1       Bel          69             90             88
# 2  Jannelle          90             95             93
# 3   Jo-anne          47             57             44
# 4       Ola          76             78             75
# 5     Angie          71             83             78

# %%
df.iloc[1]
# Out:
# name                   Bel
# gender              female
# race/ethnicity     group C
# lunch             standard
# math score              69
# reading score           90
# writing score           88
# Name: 1, dtype: object

# %%
for index, row in df.iterrows():
    print(index,row)
# Out:
# 0 name                 Jenan
# gender              female
# race/ethnicity     group B
# lunch             standard
# math score              72
# reading score           72
# writing score           74
# Name: 0, dtype: object
# 1 name                   Bel
# gender              female
# race/ethnicity     group C
# lunch             standard
# math score              69
# reading score           90
# writing score           88
# Name: 1, dtype: object
# 2 name              Jannelle
# gender              female
# race/ethnicity     group B
# lunch             standard
# math score              90
# reading score           95
# writing score           93
# Name: 2, dtype: object
# 3 name                   Jo-anne
# gender                    male
# race/ethnicity         group A
# lunch             free/reduced
# math score                  47
# reading score               57
# writing score               44
# Name: 3, dtype: object
# 4 name                   Ola
# ...

# %%
df[(df['gender']=='male')&(df['race/ethnicity']=='group A')]
# Out:
#           name gender race/ethnicity         lunch  math score  reading score  \
# 3      Jo-anne   male        group A  free/reduced          47             57
# 13       Halli   male        group A      standard          78             72
# 25     Chilton   male        group A  free/reduced          73             74
# 61       Dasya   male        group A  free/reduced          39             39
# 62      Jervis   male        group A  free/reduced          62             61
# 77   Kara-lynn   male        group A      standard          80             78
# 82         Gus   male        group A  free/reduced          50             47
# 112      Jamie   male        group A      standard          54             53
# 143      Milli   male        group A      standard          57             43
# 150      Camel   male        group A      standard          62             67
# 151     Grange   male        group A      standard          77             67
# ...

# %%
df[(df['math score']>=50)&(df['reading score']>=90)].head()
# Out:
#          name  gender race/ethnicity         lunch  math score  reading score  \
# 1         Bel  female        group C      standard          69             90
# 2    Jannelle  female        group B      standard          90             95
# 6       Marga  female        group B      standard          88             95
# 38       Noak  female        group D  free/reduced          75             90
# 102    Pavlov  female        group D      standard          85             91
#
#      writing score
# 1               88
# 2               93
# 6               92
# 38              88
# 102             89

# %%
df.loc[(df['math score']>=50)&(df['reading score']>=90)&(df['lunch']=='standard')].head()
# Out:
#          name  gender race/ethnicity     lunch  math score  reading score  \
# 1         Bel  female        group C  standard          69             90
# 2    Jannelle  female        group B  standard          90             95
# 6       Marga  female        group B  standard          88             95
# 102    Pavlov  female        group D  standard          85             91
# 106     Ddene  female        group D  standard          87            100
#
#      writing score
# 1               88
# 2               93
# 6               92
# 102             89
# 106            100

# %%
df.describe()
# Out:
#        math score  reading score  writing score
# count   249.00000     249.000000     249.000000
# mean     65.02008      67.939759      66.670683
# std      15.70634      15.529900      15.766312
# min       0.00000      17.000000      10.000000
# 25%      55.00000      56.000000      56.000000
# 50%      65.00000      69.000000      68.000000
# 75%      76.00000      80.000000      77.000000
# max     100.00000     100.000000     100.000000
